# %%
import pandas as pd
from functools import reduce
import os

# %%
resource_path = './data'
only_files = [os.path.join(resource_path, f) for f in os.listdir(resource_path) if os.path.isfile(os.path.join(resource_path, f)) 
              and f.find('.csv') != -1]
dfs = []
for f in only_files:
    df = pd.read_csv(f)
    dfs.append(df)
citibike_combo = pd.concat(dfs)
citibike_combo.head()
citibike_combo.to_csv('citibike_combo_data.csv', sep = ',')
citibike_combo.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           316  2019-06-01 00:05:55.7210  2019-06-01 00:11:11.9940
# 1           280  2019-06-01 00:08:09.0920  2019-06-01 00:12:50.0730
# 2          2162  2019-06-01 00:13:11.8800  2019-06-01 00:49:14.3640
# 3          2184  2019-06-01 00:13:30.1110  2019-06-01 00:49:54.2250
# 4           139  2019-06-01 00:13:31.8520  2019-06-01 00:15:51.7880
#
#    start station id start station name  start station latitude  \
# 0              3187          Warren St               40.721124
# 1              3185          City Hall               40.717733
# 2              3199       Newport Pkwy               40.728745
# 3              3199       Newport Pkwy               40.728745
# 4              3207        Oakland Ave               40.737604
#
#    start station longitude  end station id end station name  \
# 0               -74.038051            3199     Newport Pkwy
# ...

# %%
filepath1 = "data/JC-201906-citibike-tripdata.csv"
jun19_df = pd.read_csv(filepath1)
jun19_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           316  2019-06-01 00:05:55.7210  2019-06-01 00:11:11.9940
# 1           280  2019-06-01 00:08:09.0920  2019-06-01 00:12:50.0730
# 2          2162  2019-06-01 00:13:11.8800  2019-06-01 00:49:14.3640
# 3          2184  2019-06-01 00:13:30.1110  2019-06-01 00:49:54.2250
# 4           139  2019-06-01 00:13:31.8520  2019-06-01 00:15:51.7880
#
#    start station id start station name  start station latitude  \
# 0              3187          Warren St               40.721124
# 1              3185          City Hall               40.717733
# 2              3199       Newport Pkwy               40.728745
# 3              3199       Newport Pkwy               40.728745
# 4              3207        Oakland Ave               40.737604
#
#    start station longitude  end station id end station name  \
# 0               -74.038051            3199     Newport Pkwy
# ...

# %%
filepath2 = "data/JC-201907-citibike-tripdata.csv"
jul19_df = pd.read_csv(filepath2)
jul19_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1793  2019-07-01 00:00:36.6150  2019-07-01 00:30:30.5940
# 1           434  2019-07-01 00:02:54.6150  2019-07-01 00:10:09.0370
# 2           251  2019-07-01 00:03:27.5670  2019-07-01 00:07:38.6080
# 3           636  2019-07-01 00:03:56.1690  2019-07-01 00:14:32.4180
# 4           623  2019-07-01 00:04:16.2060  2019-07-01 00:14:40.0500
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3206            Hilltop               40.731169
# 2              3186      Grove St PATH               40.719586
# 3              3206            Hilltop               40.731169
# 4              3206            Hilltop               40.731169
#
#    start station longitude  end station id     end station name  \
# 0               -74.043117            3198     Heights Elevator
# ...

# %%
filepath3 = "data/JC-201908-citibike-tripdata.csv"
aug19_df = pd.read_csv(filepath3)
aug19_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           261  2019-08-01 00:14:55.9900  2019-08-01 00:19:17.4780
# 1           172  2019-08-01 00:23:06.9910  2019-08-01 00:25:59.1480
# 2           525  2019-08-01 00:23:28.6170  2019-08-01 00:32:13.7000
# 3           219  2019-08-01 00:32:36.1410  2019-08-01 00:36:15.2730
# 4           262  2019-08-01 00:41:26.6700  2019-08-01 00:45:49.3530
#
#    start station id start station name  start station latitude  \
# 0              3205  JC Medical Center               40.716540
# 1              3279        Dixon Mills               40.721630
# 2              3199       Newport Pkwy               40.728745
# 3              3187          Warren St               40.721124
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id    end station name  \
# 0               -74.049638            3192  Liberty Light Rail
# ...

# %%
filepath4 = "data/JC-202006-citibike-tripdata.csv"
jun20_df = pd.read_csv(filepath4)
jun20_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           122  2020-06-01 00:02:21.7500  2020-06-01 00:04:24.3250
# 1          1282  2020-06-01 00:12:27.1090  2020-06-01 00:33:50.0540
# 2           186  2020-06-01 01:19:59.2090  2020-06-01 01:23:05.8930
# 3           131  2020-06-01 01:26:42.2050  2020-06-01 01:28:53.8040
# 4           266  2020-06-01 01:27:33.7090  2020-06-01 01:32:00.1890
#
#    start station id          start station name  start station latitude  \
# 0              3792  Columbus Dr at Exchange Pl               40.716870
# 1              3198            Heights Elevator               40.748716
# 2              3275              Columbus Drive               40.718355
# 3              3267                Morris Canal               40.712419
# 4              3639                  Harborside               40.719252
#
#    start station longitude  end station id  end station name  \
# ...

# %%
filepath5 = "data/JC-202007-citibike-tripdata.csv"
jul20_df = pd.read_csv(filepath5)
jul20_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          2333  2020-07-01 00:23:19.8220  2020-07-01 01:02:13.2980
# 1          1203  2020-07-01 00:27:45.2420  2020-07-01 00:47:49.1960
# 2           786  2020-07-01 00:34:17.8680  2020-07-01 00:47:24.6310
# 3          1488  2020-07-01 00:51:07.5310  2020-07-01 01:15:56.0200
# 4          2682  2020-07-01 00:51:16.3880  2020-07-01 01:35:58.4590
#
#    start station id          start station name  start station latitude  \
# 0              3694              Jackson Square               40.711130
# 1              3791  Hoboken Ave at Monmouth St               40.735208
# 2              3792  Columbus Dr at Exchange Pl               40.716870
# 3              3677                Glenwood Ave               40.727551
# 4              3191                    Union St               40.718211
#
#    start station longitude  end station id       end station name  \
# ...

# %%
filepath6 = "data/JC-202008-citibike-tripdata.csv"
aug20_df = pd.read_csv(filepath6)
aug20_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           561  2020-08-01 00:00:16.5960  2020-08-01 00:09:38.5610
# 1           236  2020-08-01 00:00:46.3900  2020-08-01 00:04:42.8890
# 2           384  2020-08-01 00:02:38.9250  2020-08-01 00:09:03.7590
# 3          1302  2020-08-01 00:03:27.0270  2020-08-01 00:25:09.2120
# 4          5561  2020-08-01 00:03:57.4810  2020-08-01 01:36:38.5000
#
#    start station id start station name  start station latitude  \
# 0              3185          City Hall               40.717733
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3185          City Hall               40.717733
# 4              3185          City Hall               40.717733
#
#    start station longitude  end station id end station name  \
# 0               -74.043845            3185        City Hall
# ...

# %%
jun19_df = jun19_df.loc[jun19_df["gender"] != 0, :]
jun19_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               316  2019-06-01 00:05:55.7210  2019-06-01 00:11:11.9940
# 1               280  2019-06-01 00:08:09.0920  2019-06-01 00:12:50.0730
# 4               139  2019-06-01 00:13:31.8520  2019-06-01 00:15:51.7880
# 5               203  2019-06-01 00:15:43.2590  2019-06-01 00:19:06.7450
# 6               671  2019-06-01 00:19:41.5790  2019-06-01 00:30:52.6600
# ...             ...                       ...                       ...
# 39425           639  2019-06-30 23:38:29.5450  2019-06-30 23:49:09.2110
# 39426           643  2019-06-30 23:38:34.9100  2019-06-30 23:49:17.9690
# 39427           418  2019-06-30 23:42:30.9400  2019-06-30 23:49:29.5360
# 39428          2529  2019-06-30 23:46:17.5700  2019-07-01 00:28:27.1710
# 39429           831  2019-06-30 23:49:01.6830  2019-07-01 00:02:53.1150
#
#        start station id start station name  start station latitude  \
# ...

# %%
jul19_df = jul19_df.loc[jul19_df["gender"] != 0, :]
jul19_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0              1793  2019-07-01 00:00:36.6150  2019-07-01 00:30:30.5940
# 1               434  2019-07-01 00:02:54.6150  2019-07-01 00:10:09.0370
# 2               251  2019-07-01 00:03:27.5670  2019-07-01 00:07:38.6080
# 3               636  2019-07-01 00:03:56.1690  2019-07-01 00:14:32.4180
# 4               623  2019-07-01 00:04:16.2060  2019-07-01 00:14:40.0500
# ...             ...                       ...                       ...
# 43741           673  2019-07-31 23:39:13.1800  2019-07-31 23:50:26.6520
# 43742           161  2019-07-31 23:41:24.1110  2019-07-31 23:44:05.4090
# 43743           310  2019-07-31 23:47:27.3940  2019-07-31 23:52:37.4870
# 43744           137  2019-07-31 23:59:29.9300  2019-08-01 00:01:47.1970
# 43745           463  2019-07-31 23:59:54.9470  2019-08-01 00:07:37.9750
#
#        start station id start station name  start station latitude  \
# ...

# %%
aug19_df = aug19_df.loc[aug19_df["gender"] != 0, :]
aug19_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               261  2019-08-01 00:14:55.9900  2019-08-01 00:19:17.4780
# 1               172  2019-08-01 00:23:06.9910  2019-08-01 00:25:59.1480
# 2               525  2019-08-01 00:23:28.6170  2019-08-01 00:32:13.7000
# 3               219  2019-08-01 00:32:36.1410  2019-08-01 00:36:15.2730
# 4               262  2019-08-01 00:41:26.6700  2019-08-01 00:45:49.3530
# ...             ...                       ...                       ...
# 48706           384  2019-08-31 23:40:45.2450  2019-08-31 23:47:09.8810
# 48707           633  2019-08-31 23:45:55.6660  2019-08-31 23:56:29.5350
# 48708           324  2019-08-31 23:50:27.9220  2019-08-31 23:55:52.8420
# 48709           126  2019-08-31 23:52:21.9250  2019-08-31 23:54:28.5820
# 48710           690  2019-08-31 23:56:55.1530  2019-09-01 00:08:25.2370
#
#        start station id start station name  start station latitude  \
# ...

# %%
combine19_df = pd.concat([jun19_df, jul19_df, aug19_df], axis=0)
combine19_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               316  2019-06-01 00:05:55.7210  2019-06-01 00:11:11.9940
# 1               280  2019-06-01 00:08:09.0920  2019-06-01 00:12:50.0730
# 4               139  2019-06-01 00:13:31.8520  2019-06-01 00:15:51.7880
# 5               203  2019-06-01 00:15:43.2590  2019-06-01 00:19:06.7450
# 6               671  2019-06-01 00:19:41.5790  2019-06-01 00:30:52.6600
# ...             ...                       ...                       ...
# 48706           384  2019-08-31 23:40:45.2450  2019-08-31 23:47:09.8810
# 48707           633  2019-08-31 23:45:55.6660  2019-08-31 23:56:29.5350
# 48708           324  2019-08-31 23:50:27.9220  2019-08-31 23:55:52.8420
# 48709           126  2019-08-31 23:52:21.9250  2019-08-31 23:54:28.5820
# 48710           690  2019-08-31 23:56:55.1530  2019-09-01 00:08:25.2370
#
#        start station id start station name  start station latitude  \
# ...

# %%
grp_combine19 = combine19_df.groupby(['gender'])

grp_combine19_df = grp_combine19.mean()
grp_combine19_df
# Out:
#         tripduration  start station id  start station latitude  \
# gender
# 1         636.276099       3298.738764               40.722701
# 2         811.270602       3289.589451               40.722695
#
#         start station longitude  end station id  end station latitude  \
# gender
# 1                    -74.046140     3296.236371             40.722328
# 2                    -74.046293     3285.613194             40.722391
#
#         end station longitude        bikeid   birth year
# gender
# 1                  -74.045744  28452.047843  1982.179101
# 2                  -74.045629  28419.757738  1984.068254

# %%
grp_user19 = combine19_df.groupby(['usertype'])
grp_user19_df = grp_user19.count()
grp_user19_df
# Out:
#             tripduration  starttime  stoptime  start station id  \
# usertype
# Customer           10694      10694     10694             10694
# Subscriber        110238     110238    110238            110238
#
#             start station name  start station latitude  \
# usertype
# Customer                 10694                   10694
# Subscriber              110238                  110238
#
#             start station longitude  end station id  end station name  \
# usertype
# Customer                      10694           10694             10694
# Subscriber                   110238          110238            110238
#
#             end station latitude  end station longitude  bikeid  birth year  \
# usertype
# Customer                   10694                  10694   10694       10694
# Subscriber                110238                 110238  110238      110238
#
#             gender
# usertype
# Customer     10694
# Subscriber  110238

# %%
jun19_df = jun19_df.loc[jun19_df["tripduration"] < 3600, :]
jun19_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               316  2019-06-01 00:05:55.7210  2019-06-01 00:11:11.9940
# 1               280  2019-06-01 00:08:09.0920  2019-06-01 00:12:50.0730
# 4               139  2019-06-01 00:13:31.8520  2019-06-01 00:15:51.7880
# 5               203  2019-06-01 00:15:43.2590  2019-06-01 00:19:06.7450
# 6               671  2019-06-01 00:19:41.5790  2019-06-01 00:30:52.6600
# ...             ...                       ...                       ...
# 39425           639  2019-06-30 23:38:29.5450  2019-06-30 23:49:09.2110
# 39426           643  2019-06-30 23:38:34.9100  2019-06-30 23:49:17.9690
# 39427           418  2019-06-30 23:42:30.9400  2019-06-30 23:49:29.5360
# 39428          2529  2019-06-30 23:46:17.5700  2019-07-01 00:28:27.1710
# 39429           831  2019-06-30 23:49:01.6830  2019-07-01 00:02:53.1150
#
#        start station id start station name  start station latitude  \
# ...

# %%
jul19_df = jul19_df.loc[jul19_df["tripduration"] < 3600, :]
jul19_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0              1793  2019-07-01 00:00:36.6150  2019-07-01 00:30:30.5940
# 1               434  2019-07-01 00:02:54.6150  2019-07-01 00:10:09.0370
# 2               251  2019-07-01 00:03:27.5670  2019-07-01 00:07:38.6080
# 3               636  2019-07-01 00:03:56.1690  2019-07-01 00:14:32.4180
# 4               623  2019-07-01 00:04:16.2060  2019-07-01 00:14:40.0500
# ...             ...                       ...                       ...
# 43741           673  2019-07-31 23:39:13.1800  2019-07-31 23:50:26.6520
# 43742           161  2019-07-31 23:41:24.1110  2019-07-31 23:44:05.4090
# 43743           310  2019-07-31 23:47:27.3940  2019-07-31 23:52:37.4870
# 43744           137  2019-07-31 23:59:29.9300  2019-08-01 00:01:47.1970
# 43745           463  2019-07-31 23:59:54.9470  2019-08-01 00:07:37.9750
#
#        start station id start station name  start station latitude  \
# ...

# %%
grp_jun19_df

# %%
dfs = [jun19_df, jul19_df, aug19_df]
df19_final = reduce(lambda left,right: pd.merge(left,right,on='bikeid'), dfs)
df19_final.head()

# %%
combined_df.to_csv("Data/combined_state.csv", encoding="utf-8", index=False, header=True)
final_df = combined_df.rename(columns={' cocktail':'cocktail', 'Image URL':'image_src'})
final_df
# Out:
#    abbr   latitude   longitude                 state  \
# 0    AL  32.601011  -86.680736               Alabama
# 1    AK  61.302501 -158.775020                Alaska
# 2    AZ  34.168219 -111.930907               Arizona
# 3    AR  34.751928  -92.131378              Arkansas
# 4    CA  37.271875 -119.270415            California
# 5    CO  38.997934 -105.550567              Colorado
# 6    CT  41.518784  -72.757507           Connecticut
# 7    DE  39.145251  -75.418921              Delaware
# 8    DC  38.899349  -77.014567  District of Columbia
# 9    FL  27.975728  -83.833017               Florida
# 10   GA  32.678125  -83.222976               Georgia
# 11   HI  20.460000 -157.505000                Hawaii
# 12   ID  45.494576 -114.142430                 Idaho
# 13   IL  39.739318  -89.504139              Illinois
# 14   IN  39.766219  -86.441277               Indiana
# 15   IA  41.938317  -93.389798                  Iowa
# 16   KS  38.498779  -98.320078                Kansas
# ...

# %% [markdown]
# ## Postgres for state table

# %%
from sqlalchemy import create_engine
from config import postgres_pwd, postgres_user

db_name = "cocktail_db"
table_name = "state"

connection_string = f"{postgres_user}:{postgres_pwd}@localhost:5432/{db_name}"
engine = create_engine(f'postgresql://{connection_string}')
conn = engine.connect()

final_df.to_sql(table_name, con=engine, if_exists="append", index=False)

conn.close()
